# %% [markdown]
# # Emotion Detection

# %% [markdown]
# **Importing Libraries**

# %%
import matplotlib.pyplot as plt
from glob import glob
import cv2
import random
import os
# %matplotlib inline

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Dense, Input, Dropout, Flatten, Conv2D
from tensorflow.keras.layers import BatchNormalization, Activation, MaxPooling2D
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.utils import plot_model

from IPython.display import SVG, Image
import tensorflow as tf
print("Tensorflow version:", tf.__version__)
# Out:
# Tensorflow version: 2.12.0

# %%
images = glob("/kaggle/input/fer2013/train/**/**")
for i in range(9):
    image = random.choice(images)
    plt.figure(figsize=(12,12))
    plt.subplot(331+i)
    plt.imshow(cv2.imread(image));
    plt.axis('off')

# %% [markdown]
# **Preparing Data for Training**

# %%
img_size = 48
batch_size = 64
datagen_train = ImageDataGenerator(horizontal_flip = True)
train_generator = datagen_train.flow_from_directory("/kaggle/input/fer2013/train/",
                                                   target_size = (img_size, img_size),
                                                   color_mode = "grayscale",
                                                   batch_size = batch_size,
                                                   class_mode = "categorical",
                                                   shuffle = True)

datagen_validation = ImageDataGenerator(horizontal_flip = True)
validation_generator = datagen_train.flow_from_directory("/kaggle/input/fer2013/test/",
                                                   target_size = (img_size, img_size),
                                                   color_mode = "grayscale",
                                                   batch_size = batch_size,
                                                   class_mode = "categorical",
                                                   shuffle = True)
# Out:
# Found 28709 images belonging to 7 classes.
# Found 7178 images belonging to 7 classes.

# %% [markdown]
# **Defining Model**

# %%
def Convolution(input_tensor, filters, kernel_size):
    x = Conv2D(filters = filters, kernel_size = kernel_size, padding = "same")(input_tensor)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = MaxPooling2D(pool_size = (2,2))(x)
    x = Dropout(0.25)(x)
    
    return x

# %%
def Dense_f(input_tensor, nodes):
    x = Dense(nodes)(input_tensor)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Dropout(0.25)(x)
    
    return x

# %%
def model_fer(input_shape):
    inputs = Input(input_shape)
    conv_1 = Convolution(inputs,64,(3,3))
    conv_2 = Convolution(conv_1,128,(5,5))
    conv_3 = Convolution(conv_2,512,(3,3))
    conv_4 = Convolution(conv_3,512,(3,3))
    
    flatten = Flatten()(conv_4)
    
    dense_1 = Dense_f(flatten, 256)
    dense_2 = Dense_f(dense_1, 512)
    
    output = Dense(7, activation = "softmax")(dense_2)
    model = Model(inputs = [inputs], outputs = [output])
    
    opt = Adam(lr = 0.0005)
    
    model.compile(loss = ['categorical_crossentropy'], optimizer = opt, metrics = ['accuracy'])
    
    return model

# %%
model = model_fer((48,48,1))
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 48, 48, 1)]       0
#
#  conv2d (Conv2D)             (None, 48, 48, 64)        640
#
#  batch_normalization (BatchN  (None, 48, 48, 64)       256
#  ormalization)
#
#  activation (Activation)     (None, 48, 48, 64)        0
#
#  max_pooling2d (MaxPooling2D  (None, 24, 24, 64)       0
#  )
#
#  dropout (Dropout)           (None, 24, 24, 64)        0
#
#  conv2d_1 (Conv2D)           (None, 24, 24, 128)       204928
#
#  batch_normalization_1 (Batc  (None, 24, 24, 128)      512
#  hNormalization)
#
#  activation_1 (Activation)   (None, 24, 24, 128)       0
#
#  max_pooling2d_1 (MaxPooling  (None, 12, 12, 128)      0
#  2D)
#
#  dropout_1 (Dropout)         (None, 12, 12, 128)       0
#
#  conv2d_2 (Conv2D)           (None, 12, 12, 512)       590336
#
#  batch_normalization_2 (Batc  (None, 12, 12, 512)      2048
#  hNormalization)
#
#  activation_2 (Activation)   (None, 12, 12, 512)       0
#
#  max_pooling2d_2 (MaxPooling  (None, 6, 6, 512)        0
#  2D)
#
#  dropout_2 (Dropout)         (None, 6, 6, 512)         0
#
#  conv2d_3 (Conv2D)           (None, 6, 6, 512)         2359808
#
#  batch_normalization_3 (Batc  (None, 6, 6, 512)        2048
#  hNormalization)
#
#  activation_3 (Activation)   (None, 6, 6, 512)         0
#
#  max_pooling2d_3 (MaxPooling  (None, 3, 3, 512)        0
#  2D)
#
#  dropout_3 (Dropout)         (None, 3, 3, 512)         0
#
#  flatten (Flatten)           (None, 4608)              0
#
#  dense (Dense)               (None, 256)               1179904
#
#  batch_normalization_4 (Batc  (None, 256)              1024
#  hNormalization)
#
#  activation_4 (Activation)   (None, 256)               0
#
#  dropout_4 (Dropout)         (None, 256)               0
#
#  dense_1 (Dense)             (None, 512)               131584
#
#  batch_normalization_5 (Batc  (None, 512)              2048
#  hNormalization)
#
#  activation_5 (Activation)   (None, 512)               0
#
#  dropout_5 (Dropout)         (None, 512)               0
#
#  dense_2 (Dense)             (None, 7)                 3591
#
# =================================================================
# Total params: 4,478,727
# Trainable params: 4,474,759
# Non-trainable params: 3,968
# _________________________________________________________________

# %% [markdown]
# **Initializing the Model**

# %%
epochs = 15
steps_per_epoch = train_generator.n//train_generator.batch_size
validation_steps = validation_generator.n//validation_generator.batch_size

checkpoint = ModelCheckpoint("model_weights.h5", monitor = 'val_accuracy', save_weights_only = True, mode = 'max', verbose = 1)
reduce_lr = ReduceLROnPlateau(monitor = 'val_loss', factor = 0.1, patience = 2, min_lr = 0.00001)
callbacks = [checkpoint, reduce_lr]

# %% [markdown]
# # Training the Model

# %%
history = model.fit(
x = train_generator,
steps_per_epoch = steps_per_epoch,
epochs = epochs,
validation_data = validation_generator, 
validation_steps = validation_steps,
callbacks = callbacks)
# Out:
# Epoch 1/15
# 2023-06-28 15:17:02.267473: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inmodel/dropout/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 448/448 [==============================] - ETA: 0s - loss: 1.7298 - accuracy: 0.3394
# Epoch 1: saving model to model_weights.h5
# 448/448 [==============================] - 259s 536ms/step - loss: 1.7298 - accuracy: 0.3394 - val_loss: 1.5373 - val_accuracy: 0.3955 - lr: 0.0010
# Epoch 2/15
# 448/448 [==============================] - ETA: 0s - loss: 1.3796 - accuracy: 0.4696
# Epoch 2: saving model to model_weights.h5
# 448/448 [==============================] - 58s 129ms/step - loss: 1.3796 - accuracy: 0.4696 - val_loss: 1.2510 - val_accuracy: 0.5138 - lr: 0.0010
# Epoch 3/15
# 448/448 [==============================] - ETA: 0s - loss: 1.2589 - accuracy: 0.5211
# Epoch 3: saving model to model_weights.h5
# 448/448 [==============================] - 58s 129ms/step - loss: 1.2589 - accuracy: 0.5211 - val_loss: 1.2120 - val_accuracy: 0.5398 - lr: 0.0010
# Epoch 4/15
# 448/448 [==============================] - ETA: 0s - loss: 1.2005 - accuracy: 0.5406
# Epoch 4: saving model to model_weights.h5
# 448/448 [==============================] - 57s 127ms/step - loss: 1.2005 - accuracy: 0.5406 - val_loss: 1.3433 - val_accuracy: 0.4852 - lr: 0.0010
# Epoch 5/15
# 448/448 [==============================] - ETA: 0s - loss: 1.1472 - accuracy: 0.5645
# Epoch 5: saving model to model_weights.h5
# 448/448 [==============================] - 57s 128ms/step - loss: 1.1472 - accuracy: 0.5645 - val_loss: 1.1638 - val_accuracy: 0.5551 - lr: 0.0010
# Epoch 6/15
# 448/448 [==============================] - ETA: 0s - loss: 1.1100 - accuracy: 0.5802
# Epoch 6: saving model to model_weights.h5
# 448/448 [==============================] - 58s 130ms/step - loss: 1.1100 - accuracy: 0.5802 - val_loss: 1.2360 - val_accuracy: 0.5212 - lr: 0.0010
# Epoch 7/15
# 448/448 [==============================] - ETA: 0s - loss: 1.0807 - accuracy: 0.5905
# Epoch 7: saving model to model_weights.h5
# 448/448 [==============================] - 67s 149ms/step - loss: 1.0807 - accuracy: 0.5905 - val_loss: 1.0923 - val_accuracy: 0.5911 - lr: 0.0010
# Epoch 8/15
# 448/448 [==============================] - ETA: 0s - loss: 1.0523 - accuracy: 0.5980
# Epoch 8: saving model to model_weights.h5
# 448/448 [==============================] - 69s 154ms/step - loss: 1.0523 - accuracy: 0.5980 - val_loss: 1.2255 - val_accuracy: 0.5462 - lr: 0.0010
# Epoch 9/15
# 448/448 [==============================] - ETA: 0s - loss: 1.0267 - accuracy: 0.6081
# Epoch 9: saving model to model_weights.h5
# 448/448 [==============================] - 57s 126ms/step - loss: 1.0267 - accuracy: 0.6081 - val_loss: 1.0727 - val_accuracy: 0.5981 - lr: 0.0010
# Epoch 10/15
# 448/448 [==============================] - ETA: 0s - loss: 0.9983 - accuracy: 0.6199
# Epoch 10: saving model to model_weights.h5
# 448/448 [==============================] - 56s 125ms/step - loss: 0.9983 - accuracy: 0.6199 - val_loss: 1.3031 - val_accuracy: 0.5096 - lr: 0.0010
# Epoch 11/15
# 448/448 [==============================] - ETA: 0s - loss: 0.9739 - accuracy: 0.6340
# Epoch 11: saving model to model_weights.h5
# 448/448 [==============================] - 57s 126ms/step - loss: 0.9739 - accuracy: 0.6340 - val_loss: 1.0542 - val_accuracy: 0.5999 - lr: 0.0010
# Epoch 12/15
# 448/448 [==============================] - ETA: 0s - loss: 0.9432 - accuracy: 0.6452
# Epoch 12: saving model to model_weights.h5
# 448/448 [==============================] - 61s 135ms/step - loss: 0.9432 - accuracy: 0.6452 - val_loss: 1.0031 - val_accuracy: 0.6249 - lr: 0.0010
# Epoch 13/15
# 448/448 [==============================] - ETA: 0s - loss: 0.9183 - accuracy: 0.6536
# Epoch 13: saving model to model_weights.h5
# 448/448 [==============================] - 57s 128ms/step - loss: 0.9183 - accuracy: 0.6536 - val_loss: 1.1407 - val_accuracy: 0.5753 - lr: 0.0010
# Epoch 14/15
# 448/448 [==============================] - ETA: 0s - loss: 0.8997 - accuracy: 0.6617
# Epoch 14: saving model to model_weights.h5
# 448/448 [==============================] - 57s 126ms/step - loss: 0.8997 - accuracy: 0.6617 - val_loss: 1.0900 - val_accuracy: 0.5869 - lr: 0.0010
# Epoch 15/15
# 448/448 [==============================] - ETA: 0s - loss: 0.8064 - accuracy: 0.6976
# Epoch 15: saving model to model_weights.h5
# 448/448 [==============================] - 66s 147ms/step - loss: 0.8064 - accuracy: 0.6976 - val_loss: 0.9498 - val_accuracy: 0.6525 - lr: 1.0000e-04

# %% [markdown]
# **Model Evaluation**

# %%
model.evaluate(validation_generator)
# Out:
# 113/113 [==============================] - 12s 104ms/step - loss: 0.9455 - accuracy: 0.6509
# [0.94552081823349, 0.6508776545524597]

# %% [markdown]
# **Plotting Loss**

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.legend(['Train', 'Validation'], loc = 'upper left')
plt.subplots_adjust(top = 1.0, bottom = 0.0, right = 0.95, left = 0.0, hspace = 0.25, wspace = 0.35)

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.legend(['Train', 'Validation'], loc = 'upper left')
plt.subplots_adjust(top = 1.0, bottom = 0.0, right = 0.95, left = 0.0, hspace = 0.25, wspace = 0.35)

# %% [markdown]
# **Saving Model**

# %%
model_json = model.to_json()
with open("model_a.json", "w") as json_file:
    json_file.write(model_json)
